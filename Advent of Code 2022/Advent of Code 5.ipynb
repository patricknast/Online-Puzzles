move 20 from 9 to 6
move 4 from 9 to 8
move 2 from 8 to 7
move 4 from 6 to 4
move 10 from 6 to 1"""

# %%
stacks = [
   'WMLF',
    'BZVMF',
    'HVRSLQ',
    'FSVQPMTJ',
    'LSW',
    'FVPMRJW',
    'JQCPNRF',
    'VHPSZWRB',
    'BMJCGHZW',
]

# %%
stacks[0] + stacks[1][-3:-1]
# Out:
# 'WMLFVM'

# %%
stacks[0][0:-2]
# Out:
# 'WM'

# %%
instruction = 'move 10 from 5 to 7'
[i for i in instruction.split(' ') if i.isnumeric() ]
# Out:
# ['10', '5', '7']

# %%
import numpy as np
list_instructions = input_array.split('\n')
list_numbers = [[i for i in instruction.split(' ') if i.isnumeric() ] for instruction in list_instructions]

# %%
stacks = [
   'WMLF',
    'BZVMF',
    'HVRSLQ',
    'FSVQPMTJ',
    'LSW',
    'FVPMRJW',
    'JQCPNRF',
    'VHPSZWRB',
    'BMJCGHZW',
]
print(stacks)
for step in list_numbers:
    num = int(step[0])
    start_stack = int(step[1]) -1
    end_stack = int(step[2]) -1
    print(num, start_stack+1,end_stack+1)
    stacks[end_stack] += stacks[start_stack][-num:][::-1]
    stacks[start_stack] = stacks[start_stack][0:-num]
    print(stacks)
print(stacks)
# Out:
# ['WMLF', 'BZVMF', 'HVRSLQ', 'FSVQPMTJ', 'LSW', 'FVPMRJW', 'JQCPNRF', 'VHPSZWRB', 'BMJCGHZW']
# 3 5 7
# ['WMLF', 'BZVMF', 'HVRSLQ', 'FSVQPMTJ', '', 'FVPMRJW', 'JQCPNRFWSL', 'VHPSZWRB', 'BMJCGHZW']
# 2 8 9
# ['WMLF', 'BZVMF', 'HVRSLQ', 'FSVQPMTJ', '', 'FVPMRJW', 'JQCPNRFWSL', 'VHPSZW', 'BMJCGHZWBR']
# 4 3 5
# ['WMLF', 'BZVMF', 'HV', 'FSVQPMTJ', 'QLSR', 'FVPMRJW', 'JQCPNRFWSL', 'VHPSZW', 'BMJCGHZWBR']
# 2 1 7
# ['WM', 'BZVMF', 'HV', 'FSVQPMTJ', 'QLSR', 'FVPMRJW', 'JQCPNRFWSLFL', 'VHPSZW', 'BMJCGHZWBR']
# 1 3 6
# ['WM', 'BZVMF', 'H', 'FSVQPMTJ', 'QLSR', 'FVPMRJWV', 'JQCPNRFWSLFL', 'VHPSZW', 'BMJCGHZWBR']
# 2 1 7
# ['', 'BZVMF', 'H', 'FSVQPMTJ', 'QLSR', 'FVPMRJWV', 'JQCPNRFWSLFLMW', 'VHPSZW', 'BMJCGHZWBR']
# 1 8 7
# ['', 'BZVMF', 'H', 'FSVQPMTJ', 'QLSR', 'FVPMRJWV', 'JQCPNRFWSLFLMWW', 'VHPSZ', 'BMJCGHZWBR']
# 4 2 8
# ['', 'B', 'H', 'FSVQPMTJ', 'QLSR', 'FVPMRJWV', 'JQCPNRFWSLFLMWW', 'VHPSZFMVZ', 'BMJCGHZWBR']
# 10 9 1
# ...

# %%
print()
